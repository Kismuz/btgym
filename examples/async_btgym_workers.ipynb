# %% [markdown]
# ### Asynchronous BTgym environment setup.
# ****
# - This example shows base setup for asynchronious execution of multiply BTgym environment instances.
#
#
# - The main idea is to utilize separate BTgymDataFeedServer process to draw random episode data samples from one main dataset and pass it to every running environment.
#
#
# - This is quite a memory saver since every env. instance holds only small piece of data (single episode). Besides, sampling and dataset management is performed in it's own process.

# %%
import sys
sys.path.insert(0,'..')

import time
import multiprocessing

from btgym import BTgymEnv, BTgymDataset

# %%
class Worker(multiprocessing.Process):
    env = None
    
    def __init__(self, env_class, worker_id, num_episodes, env_config):
        super(Worker, self).__init__()
        self.env_class = env_class
        self.num_episodes = num_episodes
        self.env_config = env_config
        self.worker_id = worker_id
        
    def run(self):
        print('worker_{}: making environment...'.format(self.worker_id))
        self.env = self.env_class(**env_config)
        
        for episode in range(self.num_episodes):
            print('worker_{}: episode {} started.'.format(self.worker_id, episode))
            obs = self.env.reset()
            done = False
            while not done:
                # Just repeat `hold` action:
                obs, reward, done, info = self.env.step(0)
            # Get and report statistic:
            stat = self.env.get_stat() 
            print(
                'worker_{}: episode {} finished, {} steps made within {} seconds.'.
                  format(self.worker_id, stat['episode'], stat['length'], stat['runtime'])
            )   
        self.env.close()
        print('worker_{}: environmnt closed.'.format(self.worker_id))

# %%
# Provide data:
MyDataset = BTgymDataset(
    filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
    start_weekdays=[0, 1, 2, 3, 4],
    episode_len_days=1, 
    episode_len_hours=23,
    episode_len_minutes=0,
    start_00=False,
    time_gap_hours=2,
)

# Setup:
num_workers = 8   # set it according to available CPU cores.
num_episodes = 2  # individual workplan.
base_port = 5000  # worker environment <--> BTgymServer communictaion, individual for every worker.
data_port = 4999  # BTgymServer <--> BTgymDataFeedServer communication, same for all workers.

workers = []

# Make data-master environment. In this example it will only serves as coordinator
# to start/stop data server, but can be exploited as full-time worker as well;
# just keep it runnung until others exit.
data_master = BTgymEnv(
    dataset=MyDataset,  # It is the only environment here for which dataset is required:
    port=5050,
    data_port=data_port,
    data_master=True,
    connect_timeout=10,  # set server connection timeout to 10 second (default is 60).
    verbose=0,
)

# Make and launch workers in separate processes:
for i in range(num_workers):
    # Worker environment configuration:
    env_config=dict(
        port=base_port + i,
        data_port=data_port,
        data_master=False,  # This option forces environmnet to seek for datafeed provider server
                            # rather to use own dataset. Thus, no dataset is specified for this env.
        connect_timeout=10,
        verbose=0,
    )
    
    # Make:
    worker = Worker(
        env_class=BTgymEnv,
        worker_id=i,
        num_episodes=num_episodes,
        env_config=env_config,
    )
    
    # Launch:
    worker.daemon = False
    worker.start()
    workers.append(worker)
    # Artificial async, no need for this in real training:
    time.sleep(0.1)
    
# Wait everyone to finish:
for worker in workers:
    worker.join()
    print('...worker_{} has joined.'.format(worker.worker_id))
    
# shutdown data server :
data_master.close()

print('data_master: environment closed.')
# Out:
# worker_0: making environment...
# worker_1: making environment...
# worker_2: making environment...
# worker_3: making environment...
# worker_4: making environment...
# worker_5: making environment...
# worker_6: making environment...
# worker_7: making environment...
# worker_0: episode 0 started.
# worker_1: episode 0 started.
# worker_2: episode 0 started.
# worker_3: episode 0 started.
# worker_4: episode 0 started.
# worker_5: episode 0 started.
# worker_6: episode 0 started.
# worker_7: episode 0 started.
# worker_1: episode 0 finished, 2819 steps made within 0:00:33.205089 seconds.
# worker_1: episode 1 started.
# worker_0: episode 0 finished, 2819 steps made within 0:00:33.369216 seconds.
# worker_0: episode 1 started.
# worker_2: episode 0 finished, 2819 steps made within 0:00:33.351503 seconds.
# worker_2: episode 1 started.
# worker_4: episode 0 finished, 2819 steps made within 0:00:33.374071 seconds.
# worker_4: episode 1 started.
# worker_5: episode 0 finished, 2819 steps made within 0:00:33.328580 seconds.
# worker_5: episode 1 started.
# worker_6: episode 0 finished, 2819 steps made within 0:00:33.257081 seconds.
# worker_6: episode 1 started.
# worker_3: episode 0 finished, 2819 steps made within 0:00:33.564290 seconds.
# worker_3: episode 1 started.
# worker_7: episode 0 finished, 2819 steps made within 0:00:33.230962 seconds.
# worker_7: episode 1 started.
# worker_1: episode 1 finished, 2819 steps made within 0:00:32.884330 seconds.
# worker_1: environmnt closed.
# worker_0: episode 1 finished, 2819 steps made within 0:00:32.951344 seconds.
# worker_0: environmnt closed.
# worker_2: episode 1 finished, 2819 steps made within 0:00:33.024059 seconds.
# worker_2: environmnt closed.
# ...worker_0 has joined.
# ...worker_1 has joined.
# worker_4: episode 1 finished, 2819 steps made within 0:00:32.988145 seconds.
# worker_4: environmnt closed.
# ...worker_2 has joined.
# worker_6: episode 1 finished, 2819 steps made within 0:00:32.933867 seconds.
# worker_6: environmnt closed.
# worker_5: episode 1 finished, 2819 steps made within 0:00:32.979804 seconds.
# worker_5: environmnt closed.
# worker_3: episode 1 finished, 2819 steps made within 0:00:32.966027 seconds.
# worker_3: environmnt closed.
# worker_7: episode 1 finished, 2819 steps made within 0:00:32.923182 seconds.
# worker_7: environmnt closed.
# ...worker_3 has joined.
# ...worker_4 has joined.
# ...worker_5 has joined.
# ...worker_6 has joined.
# ...worker_7 has joined.
# data_master: environment closed.

# %% [markdown]
# ### Under the hood:
# *****
# ...for those who interested in what internal communications are going on:
#
# - just set **`verbose=2*`**:
#
#
# *-DEBUG level - do not use that in real life due to data overflood.

# %%
MyDataset = BTgymDataset(
    filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
    start_weekdays=[0, 1, 2, 3, 4],
    episode_len_days=1, 
    episode_len_hours=23,
    episode_len_minutes=0,
    start_00=False,
    time_gap_hours=2,
)

env1 = BTgymEnv(
    dataset=MyDataset,
    port=5050,
    data_port=4999,
    data_master=True,
    connect_timeout=5,
    verbose=2,
)

env2 = BTgymEnv(
    port=5052,
    data_port=4999,
    data_master=False,
    connect_timeout=5,
    verbose=2,
)

_1 = env1.reset()
_2 = env2.reset()

env2.close()
env1.close()
# Out:
# [2017-08-07 20:25:33,896] Custom Dataset class used.
# [2017-08-07 20:25:34,041] DataServer PID: 3217
# [2017-08-07 20:25:34,839] Loaded 372678 records from <../examples/data/DAT_ASCII_EURUSD_M1_2016.csv>.
# [2017-08-07 20:25:34,932] Data summary:
#                 open           high            low          close    volume
# count  372678.000000  372678.000000  372678.000000  372678.000000  372678.0
# mean        1.107109       1.107198       1.107019       1.107108       0.0
# std         0.024843       0.024840       0.024847       0.024844       0.0
# min         1.035250       1.035470       1.035220       1.035220       0.0
# 25%         1.092140       1.092230       1.092040       1.092140       0.0
# 50%         1.113530       1.113610       1.113450       1.113530       0.0
# 75%         1.124710       1.124780       1.124630       1.124710       0.0
# max         1.161440       1.161600       1.160770       1.161450       0.0
# [2017-08-07 20:25:34,934] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:34,936] Respective number of steps: 2820.
# [2017-08-07 20:25:34,937] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:34,940] Episode start: 2016-11-22 06:33:00, weekday: 1.
# [2017-08-07 20:25:34,959] Episode duration: 1 day, 23:03:00.
# [2017-08-07 20:25:34,961] Total episode time gap: 0:03:00.
# [2017-08-07 20:25:34,962] Sample accepted.
# [2017-08-07 20:25:34,964] Episode filename: <_episode_dataset_2016-11-22 06:33:00>.
# [2017-08-07 20:25:35,042] Pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-08-07 20:25:35,044] DataServer received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:35,046] DataServer sent: {'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}
# [2017-08-07 20:25:35,047] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:35,048] Respective number of steps: 2820.
# [2017-08-07 20:25:35,050] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:35,052] Episode start: 2016-11-11 12:21:00, weekday: 4.
# [2017-08-07 20:25:35,055] Episode duration: 3 days, 23:09:00.
# [2017-08-07 20:25:35,056] Data_server seems ready with response: <{'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}>
# [2017-08-07 20:25:35,057] Total episode time gap: 2 days, 0:09:00.
# [2017-08-07 20:25:35,058] Duration too big, resampling...
#
# [2017-08-07 20:25:35,061] Episode start: 2016-10-17 20:53:00, weekday: 0.
# [2017-08-07 20:25:35,064] Episode duration: 1 day, 23:12:00.
# [2017-08-07 20:25:35,066] Total episode time gap: 0:12:00.
# [2017-08-07 20:25:35,067] Sample accepted.
# [2017-08-07 20:25:35,068] Episode filename: <_episode_dataset_2016-10-17 20:53:00>.
# [2017-08-07 20:25:35,084] DataServer received <{'ctrl': '_get_info'}>
# [2017-08-07 20:25:35,085] Sending info.
# [2017-08-07 20:25:35,087] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:35,088] Respective number of steps: 2820.
# [2017-08-07 20:25:35,090] Maximum allowed data time gap set to: 2:00:00.
# [2017-08-07 20:25:35,090] Base Cerebro class used. Base Strategy class used.
#
# [2017-08-07 20:25:35,095] Episode duration: 3 days, 23:10:00.
# [2017-08-07 20:25:35,092] Episode start: 2016-08-25 11:26:00, weekday: 3.
# [2017-08-07 20:25:35,096] Inferring obs. space high/low form dataset: 1.035220 / 1.161600.
# [2017-08-07 20:25:35,097] Total episode time gap: 2 days, 0:10:00.
# [2017-08-07 20:25:35,098] Obs. shape: (10, 4)
# [2017-08-07 20:25:35,098] Duration too big, resampling...
# [2017-08-07 20:25:35,102] Episode start: 2016-10-07 10:44:00, weekday: 4.
#
# [2017-08-07 20:25:35,104] Obs. min:
# [[ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]]
# max:
# [[ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]]
# [2017-08-07 20:25:35,105] Episode duration: 3 days, 23:11:00.
# [2017-08-07 20:25:35,107] Total episode time gap: 2 days, 0:11:00.
# [2017-08-07 20:25:35,108] Duration too big, resampling...
#
# [2017-08-07 20:25:35,111] Episode start: 2016-07-04 01:05:00, weekday: 0.
# [2017-08-07 20:25:35,114] Episode duration: 1 day, 23:04:00.
# [2017-08-07 20:25:35,116] Total episode time gap: 0:04:00.
# [2017-08-07 20:25:35,117] Sample accepted.
# [2017-08-07 20:25:35,118] Episode filename: <_episode_dataset_2016-07-04 01:05:00>.
# [2017-08-07 20:25:35,145] BTgymServer PID: 3222
# [2017-08-07 20:25:35,148] BtgymServer: pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-08-07 20:25:35,150] DataServer received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:35,151] DataServer sent: {'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}
# [2017-08-07 20:25:35,153] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:35,154] Respective number of steps: 2820.
# [2017-08-07 20:25:35,155] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:35,158] Episode start: 2016-07-04 08:50:00, weekday: 0.
# [2017-08-07 20:25:35,161] Episode duration: 1 day, 23:04:00.
# [2017-08-07 20:25:35,161] BTgymServer: Data_server seems ready with response: <{'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}>
# [2017-08-07 20:25:35,162] Total episode time gap: 0:04:00.
# [2017-08-07 20:25:35,164] Sample accepted.
# [2017-08-07 20:25:35,166] Episode filename: <_episode_dataset_2016-07-04 08:50:00>.
# [2017-08-07 20:25:36,143] Server started, pinging tcp://127.0.0.1:5050 ...
# [2017-08-07 20:25:36,146] Server Control mode: received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:36,147] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:36,159] Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2017-08-07 20:25:36,160] Environment is ready.
# [2017-08-07 20:25:36,165] Pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-08-07 20:25:36,166] DataServer received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:36,167] DataServer sent: {'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}
# [2017-08-07 20:25:36,169] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:36,170] Respective number of steps: 2820.
# [2017-08-07 20:25:36,171] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:36,174] Episode start: 2016-09-12 11:08:00, weekday: 0.
# [2017-08-07 20:25:36,177] Episode duration: 1 day, 23:02:00.
# [2017-08-07 20:25:36,178] Data_server seems ready with response: <{'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}>
# [2017-08-07 20:25:36,178] Total episode time gap: 0:02:00.
# [2017-08-07 20:25:36,179] Sample accepted.
# [2017-08-07 20:25:36,181] Episode filename: <_episode_dataset_2016-09-12 11:08:00>.
# [2017-08-07 20:25:36,195] DataServer received <{'ctrl': '_get_info'}>
# [2017-08-07 20:25:36,197] Sending info.
# [2017-08-07 20:25:36,199] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:36,200] Respective number of steps: 2820.
# [2017-08-07 20:25:36,201] Base Cerebro class used. Base Strategy class used.
# [2017-08-07 20:25:36,202] Maximum allowed data time gap set to: 2:00:00.
# [2017-08-07 20:25:36,204] Episode start: 2016-04-25 20:38:00, weekday: 0.
#
# [2017-08-07 20:25:36,207] Inferring obs. space high/low form dataset: 1.035220 / 1.161600.
# [2017-08-07 20:25:36,208] Episode duration: 1 day, 23:02:00.
# [2017-08-07 20:25:36,209] Obs. shape: (10, 4)
# [2017-08-07 20:25:36,209] Total episode time gap: 0:02:00.
# [2017-08-07 20:25:36,212] Episode filename: <_episode_dataset_2016-04-25 20:38:00>.
# [2017-08-07 20:25:36,211] Sample accepted.
# [2017-08-07 20:25:36,214] Obs. min:
# [[ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]
#  [ 1.03522  1.03522  1.03522  1.03522]]
# max:
# [[ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]
#  [ 1.1616  1.1616  1.1616  1.1616]]
# [2017-08-07 20:25:36,252] BTgymServer PID: 3227
# [2017-08-07 20:25:36,256] BtgymServer: pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-08-07 20:25:36,258] DataServer received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:36,260] DataServer sent: {'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}
# [2017-08-07 20:25:36,261] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:36,262] Respective number of steps: 2820.
# [2017-08-07 20:25:36,263] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:36,266] Episode start: 2016-06-01 13:03:00, weekday: 2.
# [2017-08-07 20:25:36,269] Episode duration: 1 day, 23:03:00.
# [2017-08-07 20:25:36,269] BTgymServer: Data_server seems ready with response: <{'ctrl': 'send control keys:  <_get_data>, <_get_info>, <_stop>.'}>
# [2017-08-07 20:25:36,271] Total episode time gap: 0:03:00.
# [2017-08-07 20:25:36,273] Sample accepted.
# [2017-08-07 20:25:36,274] Episode filename: <_episode_dataset_2016-06-01 13:03:00>.
# [2017-08-07 20:25:37,252] Server started, pinging tcp://127.0.0.1:5052 ...
# [2017-08-07 20:25:37,255] Server Control mode: received <{'ctrl': 'ping!'}>
# [2017-08-07 20:25:37,256] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:37,267] Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2017-08-07 20:25:37,268] Environment is ready.
# [2017-08-07 20:25:37,269] Server Control mode: received <{'ctrl': '_done'}>
# [2017-08-07 20:25:37,271] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:37,272] FORCE CONTROL MODE attempt: 1.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:37,273] Server Control mode: received <{'ctrl': '_reset'}>
# [2017-08-07 20:25:37,275] Starting episode.
# [2017-08-07 20:25:37,278] DataServer received <{'ctrl': '_get_data'}>
# [2017-08-07 20:25:37,279] Sending episode #0 data.
# [2017-08-07 20:25:37,281] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:37,283] Respective number of steps: 2820.
# [2017-08-07 20:25:37,284] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:37,287] Episode start: 2016-11-14 03:19:00, weekday: 0.
# [2017-08-07 20:25:37,291] Episode duration: 1 day, 23:01:00.
# [2017-08-07 20:25:37,292] Total episode time gap: 0:01:00.
# [2017-08-07 20:25:37,292] Data_server responded with datafeed in about 0.01 seconds.
# [2017-08-07 20:25:37,293] Sample accepted.
# [2017-08-07 20:25:37,295] Episode filename: <_episode_dataset_2016-11-14 03:19:00>.
# [2017-08-07 20:25:37,298] Kwargs:
# {}
#
# [2017-08-07 20:25:37,310] Inner time embedding: 10
# [2017-08-07 20:25:37,311] COMM recieved: {'action': 'hold'}
# [2017-08-07 20:25:37,324] Env response checker received:
# (array([[ 1.11726,  1.11724,  1.11737,  1.11731],
#        [ 1.11729,  1.11728,  1.1173 ,  1.11728],
#        [ 1.11728,  1.11727,  1.11737,  1.11728],
#        [ 1.11728,  1.11728,  1.11789,  1.11788],
#        [ 1.11786,  1.11777,  1.1182 ,  1.11819],
#        [ 1.1182 ,  1.11818,  1.11835,  1.1183 ],
#        [ 1.1183 ,  1.1181 ,  1.11841,  1.11841],
#        [ 1.11841,  1.11809,  1.11884,  1.11809],
#        [ 1.11811,  1.11801,  1.11819,  1.11812],
#        [ 1.11813,  1.1179 ,  1.11815,  1.11809]]), 0.0, False, [{'step': 1, 'time': datetime.datetime(2016, 6, 1, 13, 12), 'action': 'hold', 'broker_message': '-', 'broker_cash': 10.0, 'broker_value': 10.0, 'drawdown': 0.0}])
# as type: <class 'tuple'>
# [2017-08-07 20:25:37,325] Server Control mode: received <{'ctrl': '_done'}>
# [2017-08-07 20:25:37,327] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:37,328] FORCE CONTROL MODE attempt: 1.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:37,329] Server Control mode: received <{'ctrl': '_reset'}>
# [2017-08-07 20:25:37,330] Starting episode.
# [2017-08-07 20:25:37,333] DataServer received <{'ctrl': '_get_data'}>
# [2017-08-07 20:25:37,335] Sending episode #1 data.
# [2017-08-07 20:25:37,337] Maximum episode time duration set to: 1 day, 23:00:00.
# [2017-08-07 20:25:37,339] Respective number of steps: 2820.
# [2017-08-07 20:25:37,340] Maximum allowed data time gap set to: 2:00:00.
#
# [2017-08-07 20:25:37,343] Episode start: 2016-09-05 11:39:00, weekday: 0.
# [2017-08-07 20:25:37,346] Episode duration: 1 day, 23:25:00.
# [2017-08-07 20:25:37,347] Data_server responded with datafeed in about 0.01 seconds.
# [2017-08-07 20:25:37,347] Total episode time gap: 0:25:00.
# [2017-08-07 20:25:37,349] Sample accepted.
# [2017-08-07 20:25:37,350] Episode filename: <_episode_dataset_2016-09-05 11:39:00>.
# [2017-08-07 20:25:37,354] Kwargs:
# {}
#
# [2017-08-07 20:25:37,366] Inner time embedding: 10
# [2017-08-07 20:25:37,368] COMM recieved: {'action': 'hold'}
# [2017-08-07 20:25:37,378] Env response checker received:
# (array([[ 1.07708,  1.07706,  1.07741,  1.07741],
#        [ 1.07738,  1.07738,  1.07758,  1.07743],
#        [ 1.07741,  1.07727,  1.07743,  1.07743],
#        [ 1.07744,  1.07732,  1.07772,  1.07732],
#        [ 1.07734,  1.07699,  1.07741,  1.07704],
#        [ 1.07702,  1.07651,  1.07706,  1.07663],
#        [ 1.07664,  1.07619,  1.07674,  1.07623],
#        [ 1.07621,  1.07576,  1.0763 ,  1.07576],
#        [ 1.07578,  1.07564,  1.07584,  1.07578],
#        [ 1.07579,  1.07566,  1.07596,  1.07571]]), 0.0, False, [{'step': 1, 'time': datetime.datetime(2016, 11, 14, 3, 28), 'action': 'hold', 'broker_message': '-', 'broker_cash': 10.0, 'broker_value': 10.0, 'drawdown': 0.0}])
# as type: <class 'tuple'>
# [2017-08-07 20:25:37,379] COMM recieved: {'ctrl': '_done'}
# [2017-08-07 20:25:37,381] FORCE CONTROL MODE attempt: 1.
# Response: _DONE SIGNAL RECEIVED
# [2017-08-07 20:25:37,381] RunStop() invoked with -
# [2017-08-07 20:25:38,337] Episode elapsed time: 0:00:01.005532.
# [2017-08-07 20:25:38,423] Server Control mode: received <{'ctrl': '_done'}>
# [2017-08-07 20:25:38,425] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:38,426] FORCE CONTROL MODE attempt: 2.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:38,427] Server Control mode: received <{'ctrl': '_stop'}>
# [2017-08-07 20:25:38,428] Server is exiting.
# [2017-08-07 20:25:38,430] Server is exiting. Exit code: None
# [2017-08-07 20:25:38,431] Environment closed.
# [2017-08-07 20:25:38,433] COMM recieved: {'ctrl': '_done'}
# [2017-08-07 20:25:38,434] FORCE CONTROL MODE attempt: 1.
# Response: _DONE SIGNAL RECEIVED
# [2017-08-07 20:25:38,434] RunStop() invoked with -
# [2017-08-07 20:25:39,384] Episode elapsed time: 0:00:02.107683.
# [2017-08-07 20:25:39,466] Server Control mode: received <{'ctrl': '_done'}>
# [2017-08-07 20:25:39,468] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:39,469] FORCE CONTROL MODE attempt: 2.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-08-07 20:25:39,470] Server Control mode: received <{'ctrl': '_stop'}>
# [2017-08-07 20:25:39,471] Server is exiting.
# [2017-08-07 20:25:39,472] Server is exiting. Exit code: None
# [2017-08-07 20:25:39,474] DataServer received <{'ctrl': '_stop'}>
# [2017-08-07 20:25:39,476] DataServer is exiting.
# [2017-08-07 20:25:39,478] DataServer is exiting. Exit code: None
# [2017-08-07 20:25:39,479] Environment closed.
